# %%
import pandas as pd
from wordcloud import WordCloud

# %%
#Load data
scotch_csv = pd.read_csv("~/Documents/datascience/datasets/whiskey_review_kaggle/scotch_review.csv", index_col=0)
scotch_csv
# Out:
#                                                    name  \
# 1                        Johnnie Walker Blue Label, 40%
# 2       Black Bowmore, 1964 vintage, 42 year old, 40.5%
# 3           Bowmore 46 year old (distilled 1964), 42.9%
# 4                        Compass Box The General, 53.4%
# 5                               Chivas Regal Ultis, 40%
# ...                                                 ...
# 2243  Duncan Taylor (distilled at Cameronbridge), Ca...
# 2244  Distillery Select 'Craiglodge' (distilled at L...
# 2245         Edradour Barolo Finish, 11 year old, 57.1%
# 2246  Highland Park, Cask #7380, 1981 vintage, 25 ye...
# 2247  Distillery Select 'Inchmoan' (distilled at Loc...
#
#                         category  review.point     price currency  \
# 1          Blended Scotch Whisky            97       225        $
# 2             Single Malt Scotch            97   4500.00        $
# 3             Single Malt Scotch            97  13500.00        $
# ...

# %%
fulltext = " ".join(scotch_csv['description'])

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

# Read the whole text.
text = fulltext

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = np.array(Image.open("images/bottle_mask.png"))

stopwords = set(STOPWORDS)
stopwords.add("said")

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=stopwords, contour_width=3, contour_color='steelblue')

# generate word cloud
wc.generate(text)

# store to file
wc.to_file("images/whiskey_wc.png")

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
